# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('clickstream_sessions.csv')

# %%
df.head()
# Out:
#    1  A1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0  2  A1        NaN        NaN        NaN        NaN        NaN        NaN
# 1  3  A2         A1        NaN        NaN        NaN        NaN        NaN
# 2  4  A1         A1         A2         A1         A2         A1         A2
# 3  5  A1         A1         A3         A1         A1         A3         A1
# 4  6  A1         A3         A1         A3         A1         A1         A3
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 0        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 1        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 2         A1         A3  ...          A3          A3          A1          A1
# 3         A1         A1  ...          A4          A1          A3          A3
# 4         A2         A3  ...          A1          A2          A2          A3
#
#   Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2          A4          A1          A1         NaN         NaN         NaN
# 3          A1          A4          A1         NaN         NaN         NaN
# 4          A1          A3          A1          A1          A3          A1
#
# [5 rows x 24 columns]

# %%
df.set_index(df.columns[0],inplace=True)

# %%
data=[]
for i in range(79):
    x=df.values[i]
    x=x[~pd.isnull(x)]
    data.append(x)
data
# Out:
# [array(['A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A2', 'A1', 'A2', 'A1', 'A2', 'A1', 'A3', 'A1', 'A3',
#         'A1', 'A1', 'A3', 'A3', 'A1', 'A1', 'A4', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A3', 'A1', 'A1', 'A3', 'A1', 'A1', 'A1', 'A2', 'A1',
#         'A2', 'A1', 'A4', 'A1', 'A3', 'A3', 'A1', 'A4', 'A1'], dtype=object),
#  array(['A1', 'A3', 'A1', 'A3', 'A1', 'A1', 'A3', 'A2', 'A3', 'A3', 'A3',
#         'A2', 'A3', 'A1', 'A2', 'A2', 'A3', 'A1', 'A3', 'A1', 'A1', 'A3',
#         'A1'], dtype=object),
#  array(['A2'], dtype=object),
#  array(['A2', 'A2', 'A2', 'A1'], dtype=object),
#  array(['A3', 'A4', 'A3', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A4', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A4', 'A4', 'A1', 'A2', 'A1', 'A3', 'A1', 'A3', 'A1'],
#        dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A4', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A3'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A4', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A3', 'A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object)]

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(data)

# %%
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages,cmap="YlGnBu")

# %%
from markovclick.viz import visualise_markov_chain
graph = visualise_markov_chain(m)
graph
